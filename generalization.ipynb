# %% [markdown]
# # PERFIL OF OVERFITTING

# %% [markdown]
# This module focuses on generalization. In order to develop some intuition about this concept, you're going to look at three figures. Assume that each dot in these figures represents a tree's position in a forest. The two colors have the following meanings:
#
# -The blue dots represent sick trees.
#
# -The orange dots represent healthy trees.![GeneralizationA.png](attachment:GeneralizationA.png)
#
# Se puede hacer un modelo muy complejo que aqui lo coja todo pero eso hace que este overfittig, es decir que esta hecho muy a medida de los datos del train y no sirva en realidad a los datos que podamos meterle nuevos.

# %% [markdown]
# Se puede hacer un modelo muy complejo que aqui lo coja todo pero eso hace que este overfittig, es decir que esta hecho muy a medida de los datos del train y no sirva en realidad a los datos que podamos meterle nuevos.
# ![GeneralizationC.png](attachment:GeneralizationC.png)
# como podemos ver aquí el modelo hecho en base a los examples del train no es ooptimo para un data set real. Esto se dice que, el modelo overfits the peculiarities of the data con la que entrenó.
